# %%
# Notebook overview: 
# This notebook builds the API for class Simulator used in simulator_final. 
# It executes the simulator with a given theta initialization (theta_init)

# Class: Simulator(circuit, noise_model, H_cost, H_head, classical_pre, data_loader, lambda0, shots, lr)
# Method: 
#   run(theta_init, n_steps) -> (theta_final, loss_hist)

# Example usage: 

import numpy as np

sim = Simulator(
    circuit = circuit,
    noise_model = noise_model, 
    H_cost = H,
    H_head = H,
    classical_pre = classical_pre, 
    data_loader = data_loader,
    lambda0 = 0.0
    shots = 128
    lr = 1e-2,
)

theta_final loss_hist = sim.run(theta_init = np.array([0.1]), n_steps = 50)
