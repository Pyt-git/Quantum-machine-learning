# %%
# Notebook overview: 
# This notebook builds the API of the trainer architecture made of 3 classes used in simulator_final.
# This architecture combines concepts from classical ML (eg ADAM) with QML (eg variational circuits)
# It implements the simulator's forward pass and compares other optimizers' performance with the classical ADAM optimizer.

# Class: HybridModel(classical_pre, circuit, H_head)
#   forward(x, theta) -> (q_feat, z)

# Class: SimpleAdam(lr = 1e-2)
#   update(theta, grad) -> updated theta

# Class: Trainer(hybrid_model, grad_estimator, optimizer, data_loader)
#   step(theta) -> (theta_new, batch_loss)

# Example usage: 

hybrid = hybridModel(classical_pre, circuit, H_head)
optimizer = SimpleAdam(lr = 1e-2)
trainer = Trainer(hybrid, grad_est, optimizer, data_loader)
theta_new, loss = trainer.step(theta)
